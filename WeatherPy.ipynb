# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 595

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?appid={weather_api_key}&q={city}&units=metric"

    # Log the url, record, and set numbers
    print(f"Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        

        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | mirny
# Processing Record 3 of Set 1 | camana
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | miri
# Processing Record 6 of Set 1 | espargos
# City not found. Skipping...
# Processing Record 7 of Set 1 | puerto natales
# Processing Record 8 of Set 1 | adamstown
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | chonchi
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | geraldton
# Processing Record 13 of Set 1 | grytviken
# Processing Record 14 of Set 1 | bridgewater
# Processing Record 15 of Set 1 | saipan
# Processing Record 16 of Set 1 | flying fish cove
# Processing Record 17 of Set 1 | mount isa
# Processing Record 18 of Set 1 | fort mcmurray
# Processing Record 19 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 20 of Set 1 | ulladulla
# Processing Record 21 of Set 1 | badger
# Processing Record 22 of Set 1 | ahau
# City not found. Skipping...
# Processing Record 23 of Set 1 | sierra grande
# Processing Record 24 of Set 1 | waitangi
# Processing Record 25 of Set 1 | katsuren-haebaru
# Processing Record 26 of Set 1 | olonkinbyen
# Processing Record 27 of Set 1 | georgetown
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | saint-pierre
# Processing Record 30 of Set 1 | la palma
# Processing Record 31 of Set 1 | formosa
# Processing Record 32 of Set 1 | whangarei
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | blackmans bay
# Processing Record 35 of Set 1 | dunedin
# Processing Record 36 of Set 1 | velingara
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | edinburgh of the seven seas
# Processing Record 39 of Set 1 | qal'at bishah
# City not found. Skipping...
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | noosa heads
# Processing Record 42 of Set 1 | wailua homesteads
# Processing Record 43 of Set 1 | kailahun
# Processing Record 44 of Set 1 | kodiak
# Processing Record 45 of Set 1 | susuman
# Processing Record 46 of Set 1 | ouellah
# City not found. Skipping...
# Processing Record 47 of Set 1 | el calafate
# Processing Record 48 of Set 1 | iskateley
# Processing Record 49 of Set 1 | atafu village
# Processing Record 50 of Set 1 | xique xique
# Processing Record 0 of Set 2 | birjand
# Processing Record 1 of Set 2 | vilyuchinsk
# Processing Record 2 of Set 2 | lihue
# Processing Record 3 of Set 2 | quelimane
# Processing Record 4 of Set 2 | talnakh
# Processing Record 5 of Set 2 | hawaiian paradise park
# Processing Record 6 of Set 2 | borogontsy
# Processing Record 7 of Set 2 | nadym
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | kapuskasing
# Processing Record 10 of Set 2 | zaozersk
# Processing Record 11 of Set 2 | san patricio
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | colonia
# Processing Record 14 of Set 2 | manay
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | alofi
# Processing Record 17 of Set 2 | sinan
# Processing Record 18 of Set 2 | enewetak
# Processing Record 19 of Set 2 | klyavlino
# Processing Record 20 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 21 of Set 2 | taoudenni
# Processing Record 22 of Set 2 | naze
# Processing Record 23 of Set 2 | bilibino
# Processing Record 24 of Set 2 | wenling
# Processing Record 25 of Set 2 | ribeira grande
# Processing Record 26 of Set 2 | pasighat
# Processing Record 27 of Set 2 | vernon
# Processing Record 28 of Set 2 | daru
# Processing Record 29 of Set 2 | pakse
# Processing Record 30 of Set 2 | callao
# Processing Record 31 of Set 2 | babol
# Processing Record 32 of Set 2 | sandnessjoen
# Processing Record 33 of Set 2 | kinkala
# Processing Record 34 of Set 2 | caiaponia
# Processing Record 35 of Set 2 | qui nhon
# Processing Record 36 of Set 2 | luderitz
# Processing Record 37 of Set 2 | longyearbyen
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | itoman
# Processing Record 40 of Set 2 | papao
# Processing Record 41 of Set 2 | punta del este
# Processing Record 42 of Set 2 | remire-montjoly
# Processing Record 43 of Set 2 | smithers
# Processing Record 44 of Set 2 | kone
# Processing Record 45 of Set 2 | avarua
# Processing Record 46 of Set 2 | ciudad melchor muzquiz
# Processing Record 47 of Set 2 | agogo
# Processing Record 48 of Set 2 | ust-nera
# Processing Record 49 of Set 2 | na klang
# Processing Record 0 of Set 3 | kamaishi
# Processing Record 1 of Set 3 | belmonte
# Processing Record 2 of Set 3 | vila franca do campo
# Processing Record 3 of Set 3 | uturoa
# Processing Record 4 of Set 3 | tremp
# Processing Record 5 of Set 3 | whitehorse
# Processing Record 6 of Set 3 | chibougamau
# Processing Record 7 of Set 3 | takoradi
# Processing Record 8 of Set 3 | barra de santo antonio
# Processing Record 9 of Set 3 | papatowai
# Processing Record 10 of Set 3 | bacuyangan
# Processing Record 11 of Set 3 | lubang
# Processing Record 12 of Set 3 | harper
# Processing Record 13 of Set 3 | happy valley-goose bay
# Processing Record 14 of Set 3 | ventspils
# Processing Record 15 of Set 3 | fort bragg
# Processing Record 16 of Set 3 | haugesund
# Processing Record 17 of Set 3 | iqaluit
# Processing Record 18 of Set 3 | akureyri
# Processing Record 19 of Set 3 | alice springs
# Processing Record 20 of Set 3 | bubaque
# Processing Record 21 of Set 3 | mount gambier
# Processing Record 22 of Set 3 | jiwani
# Processing Record 23 of Set 3 | ola
# Processing Record 24 of Set 3 | abengourou
# Processing Record 25 of Set 3 | tura
# Processing Record 26 of Set 3 | holualoa
# Processing Record 27 of Set 3 | verkhnevilyuysk
# Processing Record 28 of Set 3 | stanley
# Processing Record 29 of Set 3 | kangding
# Processing Record 30 of Set 3 | klyuchi
# Processing Record 31 of Set 3 | san antonio de pale
# Processing Record 32 of Set 3 | mount pearl
# Processing Record 33 of Set 3 | ingraj bazar
# Processing Record 34 of Set 3 | hasaki
# Processing Record 35 of Set 3 | port elizabeth
# Processing Record 36 of Set 3 | manjakandriana
# Processing Record 37 of Set 3 | howrah
# Processing Record 38 of Set 3 | aiken
# Processing Record 39 of Set 3 | kayangel
# Processing Record 40 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 41 of Set 3 | marquette
# Processing Record 42 of Set 3 | broken hill
# Processing Record 43 of Set 3 | college
# Processing Record 44 of Set 3 | kavaratti
# Processing Record 45 of Set 3 | tindouf
# Processing Record 46 of Set 3 | anadyr
# Processing Record 47 of Set 3 | rustaq
# Processing Record 48 of Set 3 | laghouat
# Processing Record 49 of Set 3 | kolonia town
# Processing Record 0 of Set 4 | bani yas city
# City not found. Skipping...
# Processing Record 1 of Set 4 | karasu mahallesi
# Processing Record 2 of Set 4 | caleta de carquin
# Processing Record 3 of Set 4 | guerrero negro
# Processing Record 4 of Set 4 | palmer
# Processing Record 5 of Set 4 | margaret river
# Processing Record 6 of Set 4 | meiganga
# Processing Record 7 of Set 4 | udachny
# Processing Record 8 of Set 4 | petrolina
# Processing Record 9 of Set 4 | scottburgh
# Processing Record 10 of Set 4 | kuala lipis
# Processing Record 11 of Set 4 | east london
# Processing Record 12 of Set 4 | sitka
# Processing Record 13 of Set 4 | kenai
# Processing Record 14 of Set 4 | qamdo
# Processing Record 15 of Set 4 | alghero
# Processing Record 16 of Set 4 | khovd
# Processing Record 17 of Set 4 | shakawe
# Processing Record 18 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 19 of Set 4 | constantia
# Processing Record 20 of Set 4 | tazovsky
# Processing Record 21 of Set 4 | st. john's
# Processing Record 22 of Set 4 | novo cruzeiro
# Processing Record 23 of Set 4 | craig
# Processing Record 24 of Set 4 | xinyuan
# Processing Record 25 of Set 4 | cooper's town
# Processing Record 26 of Set 4 | olyokminsk
# Processing Record 27 of Set 4 | richards bay
# Processing Record 28 of Set 4 | whyalla stuart
# City not found. Skipping...
# Processing Record 29 of Set 4 | udangudi
# Processing Record 30 of Set 4 | kittila
# Processing Record 31 of Set 4 | aral
# Processing Record 32 of Set 4 | pacific grove
# Processing Record 33 of Set 4 | touros
# Processing Record 34 of Set 4 | sinabang
# Processing Record 35 of Set 4 | pokrovsk
# Processing Record 36 of Set 4 | canoinhas
# Processing Record 37 of Set 4 | harstad
# Processing Record 38 of Set 4 | maham
# Processing Record 39 of Set 4 | astravyets
# Processing Record 40 of Set 4 | nova vicosa
# Processing Record 41 of Set 4 | conceicao da barra
# Processing Record 42 of Set 4 | qaqortoq
# Processing Record 43 of Set 4 | utrik
# Processing Record 44 of Set 4 | port douglas
# Processing Record 45 of Set 4 | punta arenas
# Processing Record 46 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 47 of Set 4 | kailua-kona
# Processing Record 48 of Set 4 | fauske
# Processing Record 49 of Set 4 | west island
# Processing Record 0 of Set 5 | weno
# Processing Record 1 of Set 5 | santa ana
# Processing Record 2 of Set 5 | masterton
# Processing Record 3 of Set 5 | isangel
# Processing Record 4 of Set 5 | luau
# Processing Record 5 of Set 5 | burang
# Processing Record 6 of Set 5 | letlhakane
# Processing Record 7 of Set 5 | namtsy
# Processing Record 8 of Set 5 | san jose village
# City not found. Skipping...
# Processing Record 9 of Set 5 | hithadhoo
# Processing Record 10 of Set 5 | brookings
# Processing Record 11 of Set 5 | mindelheim
# Processing Record 12 of Set 5 | bargara
# City not found. Skipping...
# Processing Record 13 of Set 5 | cova figueira
# Processing Record 14 of Set 5 | port lincoln
# Processing Record 15 of Set 5 | tralee
# Processing Record 16 of Set 5 | yacimiento rio turbio
# Processing Record 17 of Set 5 | belgrade
# Processing Record 18 of Set 5 | aasiaat
# Processing Record 19 of Set 5 | inarajan village
# Processing Record 20 of Set 5 | crane
# Processing Record 21 of Set 5 | gadzhiyevo
# Processing Record 22 of Set 5 | sinop
# Processing Record 23 of Set 5 | ciprian porumbescu
# Processing Record 24 of Set 5 | north elba
# Processing Record 25 of Set 5 | chernyshevsk
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | pando
# Processing Record 28 of Set 5 | minas de marcona
# Processing Record 29 of Set 5 | antsiranana
# Processing Record 30 of Set 5 | port mathurin
# Processing Record 31 of Set 5 | yung shue wan
# Processing Record 32 of Set 5 | kirovskiy
# Processing Record 33 of Set 5 | kuloy
# Processing Record 34 of Set 5 | vadso
# Processing Record 35 of Set 5 | usogorsk
# Processing Record 36 of Set 5 | svislach
# Processing Record 37 of Set 5 | acarau
# Processing Record 38 of Set 5 | lompoc
# Processing Record 39 of Set 5 | santa maria
# Processing Record 40 of Set 5 | brownfield
# Processing Record 41 of Set 5 | ancud
# Processing Record 42 of Set 5 | sydney
# Processing Record 43 of Set 5 | steyerberg
# Processing Record 44 of Set 5 | isafjordur
# Processing Record 45 of Set 5 | luanda
# Processing Record 46 of Set 5 | glace bay
# Processing Record 47 of Set 5 | egilsstadir
# Processing Record 48 of Set 5 | okhotsk
# Processing Record 49 of Set 5 | luganville
# Processing Record 0 of Set 6 | port hedland
# Processing Record 1 of Set 6 | tangalle
# Processing Record 2 of Set 6 | yagry
# City not found. Skipping...
# Processing Record 3 of Set 6 | kavieng
# Processing Record 4 of Set 6 | dudinka
# Processing Record 5 of Set 6 | natal
# Processing Record 6 of Set 6 | sonbong
# Processing Record 7 of Set 6 | puerto ayora
# Processing Record 8 of Set 6 | funadhoo
# Processing Record 9 of Set 6 | keflavik
# Processing Record 10 of Set 6 | aykhal
# Processing Record 11 of Set 6 | jiazi
# Processing Record 12 of Set 6 | invercargill
# Processing Record 13 of Set 6 | kazanskoye
# Processing Record 14 of Set 6 | hilo
# Processing Record 15 of Set 6 | nemuro
# Processing Record 16 of Set 6 | carqueiranne
# Processing Record 17 of Set 6 | najran
# Processing Record 18 of Set 6 | romanovka
# Processing Record 19 of Set 6 | haiku-pauwela
# Processing Record 20 of Set 6 | voskresenskoye
# Processing Record 21 of Set 6 | fort st. john
# Processing Record 22 of Set 6 | coahuayana de hidalgo
# Processing Record 23 of Set 6 | sakaiminato
# Processing Record 24 of Set 6 | buka
# Processing Record 25 of Set 6 | codrington
# Processing Record 26 of Set 6 | la passe
# Processing Record 27 of Set 6 | mogocha
# Processing Record 28 of Set 6 | tevragh zeina
# City not found. Skipping...
# Processing Record 29 of Set 6 | hobyo
# Processing Record 30 of Set 6 | puerto deseado
# Processing Record 31 of Set 6 | sikandra
# Processing Record 32 of Set 6 | strathalbyn
# Processing Record 33 of Set 6 | sao jose da coroa grande
# Processing Record 34 of Set 6 | queenstown
# Processing Record 35 of Set 6 | verdal
# Processing Record 36 of Set 6 | la ronge
# Processing Record 37 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 38 of Set 6 | kichha
# Processing Record 39 of Set 6 | baghlan
# Processing Record 40 of Set 6 | pedernales
# Processing Record 41 of Set 6 | sarvar
# Processing Record 42 of Set 6 | muzayri'
# City not found. Skipping...
# Processing Record 43 of Set 6 | coquimbo
# Processing Record 44 of Set 6 | villanueva
# Processing Record 45 of Set 6 | kiraz
# Processing Record 46 of Set 6 | aitape
# Processing Record 47 of Set 6 | carutapera
# Processing Record 48 of Set 6 | mahabe
# City not found. Skipping...
# Processing Record 49 of Set 6 | nizhnesortymskiy
# Processing Record 0 of Set 7 | bodo
# Processing Record 1 of Set 7 | valparaiso
# Processing Record 2 of Set 7 | fort-shevchenko
# Processing Record 3 of Set 7 | arraial do cabo
# Processing Record 4 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 5 of Set 7 | arawa
# Processing Record 6 of Set 7 | ilulissat
# Processing Record 7 of Set 7 | mabaruma
# Processing Record 8 of Set 7 | pisco
# Processing Record 9 of Set 7 | magadan
# Processing Record 10 of Set 7 | bam
# Processing Record 11 of Set 7 | horta
# Processing Record 12 of Set 7 | tabou
# Processing Record 13 of Set 7 | zouerate
# Processing Record 14 of Set 7 | laguna
# Processing Record 15 of Set 7 | khorixas
# Processing Record 16 of Set 7 | dampit
# Processing Record 17 of Set 7 | talagutong
# Processing Record 18 of Set 7 | green river
# Processing Record 19 of Set 7 | rabo de peixe
# Processing Record 20 of Set 7 | usinsk
# Processing Record 21 of Set 7 | opuwo
# Processing Record 22 of Set 7 | iwon-up
# Processing Record 23 of Set 7 | dul'durga
# Processing Record 24 of Set 7 | kuraymah
# Processing Record 25 of Set 7 | watseka
# Processing Record 26 of Set 7 | ust'-ilimsk
# Processing Record 27 of Set 7 | thinadhoo
# Processing Record 28 of Set 7 | pochinki
# Processing Record 29 of Set 7 | oral
# Processing Record 30 of Set 7 | ndele
# Processing Record 31 of Set 7 | comiso
# Processing Record 32 of Set 7 | port alfred
# Processing Record 33 of Set 7 | palmas
# Processing Record 34 of Set 7 | port blair
# Processing Record 35 of Set 7 | san sebastian de la gomera
# Processing Record 36 of Set 7 | korsakov
# Processing Record 37 of Set 7 | manavalakurichi
# Processing Record 38 of Set 7 | bakanas
# Processing Record 39 of Set 7 | laishevo
# Processing Record 40 of Set 7 | beyneu
# Processing Record 41 of Set 7 | hamilton
# Processing Record 42 of Set 7 | hadibu
# Processing Record 43 of Set 7 | dison
# Processing Record 44 of Set 7 | undurkhaan
# Processing Record 45 of Set 7 | nizhneangarsk
# Processing Record 46 of Set 7 | shakhun'ya
# Processing Record 47 of Set 7 | polyarnyy
# Processing Record 48 of Set 7 | new norfolk
# Processing Record 49 of Set 7 | djebeniana
# Processing Record 0 of Set 8 | zhigalovo
# Processing Record 1 of Set 8 | namibe
# Processing Record 2 of Set 8 | bel ombre
# Processing Record 3 of Set 8 | galliano
# Processing Record 4 of Set 8 | galle
# Processing Record 5 of Set 8 | nuku'alofa
# Processing Record 6 of Set 8 | crucecita
# Processing Record 7 of Set 8 | ringkobing
# Processing Record 8 of Set 8 | cheremushki
# Processing Record 9 of Set 8 | sangkhla buri
# Processing Record 10 of Set 8 | maile
# Processing Record 11 of Set 8 | altai
# Processing Record 12 of Set 8 | troitsko-pechorsk
# Processing Record 13 of Set 8 | vorgashor
# Processing Record 14 of Set 8 | pangody
# Processing Record 15 of Set 8 | wau
# Processing Record 16 of Set 8 | masuguru
# Processing Record 17 of Set 8 | itacare
# Processing Record 18 of Set 8 | binji
# Processing Record 19 of Set 8 | tejen
# Processing Record 20 of Set 8 | shima
# Processing Record 21 of Set 8 | talcahuano
# Processing Record 22 of Set 8 | salalah
# Processing Record 23 of Set 8 | brisas de zicatela
# Processing Record 24 of Set 8 | chengzhong
# Processing Record 25 of Set 8 | ribas do rio pardo
# Processing Record 26 of Set 8 | korla
# Processing Record 27 of Set 8 | untolovo
# City not found. Skipping...
# Processing Record 28 of Set 8 | nizhniye achaluki
# Processing Record 29 of Set 8 | tamanrasset
# Processing Record 30 of Set 8 | wynyard
# Processing Record 31 of Set 8 | apricena
# Processing Record 32 of Set 8 | greenville
# Processing Record 33 of Set 8 | ulanhot
# Processing Record 34 of Set 8 | olinda
# Processing Record 35 of Set 8 | ryotsu-minato
# Processing Record 36 of Set 8 | inhambane
# Processing Record 37 of Set 8 | gorom-gorom
# Processing Record 38 of Set 8 | tolanaro
# Processing Record 39 of Set 8 | tofol
# Processing Record 40 of Set 8 | shenjiamen
# Processing Record 41 of Set 8 | aldinga beach
# Processing Record 42 of Set 8 | sipalay
# Processing Record 43 of Set 8 | soma
# Processing Record 44 of Set 8 | valentin gomez farias
# Processing Record 45 of Set 8 | soio
# Processing Record 46 of Set 8 | carnarvon
# Processing Record 47 of Set 8 | qarqaraly
# Processing Record 48 of Set 8 | alaghsas
# Processing Record 49 of Set 8 | ponmana
# City not found. Skipping...
# Processing Record 0 of Set 9 | jinja
# Processing Record 1 of Set 9 | lupane
# Processing Record 2 of Set 9 | rovaniemi
# Processing Record 3 of Set 9 | huron
# Processing Record 4 of Set 9 | whitecourt
# Processing Record 5 of Set 9 | igarka
# Processing Record 6 of Set 9 | zuyevka
# Processing Record 7 of Set 9 | canete
# Processing Record 8 of Set 9 | cassilandia
# Processing Record 9 of Set 9 | yarmouth
# Processing Record 10 of Set 9 | vila velha
# Processing Record 11 of Set 9 | argostolion
# Processing Record 12 of Set 9 | lilongwe
# Processing Record 13 of Set 9 | luebo
# Processing Record 14 of Set 9 | hammerfest
# Processing Record 15 of Set 9 | znamenka
# Processing Record 16 of Set 9 | baise city
# Processing Record 17 of Set 9 | fortuna
# Processing Record 18 of Set 9 | zhangye
# Processing Record 19 of Set 9 | birao
# Processing Record 20 of Set 9 | sos'va
# Processing Record 21 of Set 9 | charters towers
# Processing Record 22 of Set 9 | muranovo
# Processing Record 23 of Set 9 | tutoia
# Processing Record 24 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 25 of Set 9 | amos
# Processing Record 26 of Set 9 | rawson
# Processing Record 27 of Set 9 | ierapetra
# Processing Record 28 of Set 9 | ipiales
# Processing Record 29 of Set 9 | williams lake
# Processing Record 30 of Set 9 | okakarara
# Processing Record 31 of Set 9 | silver city
# Processing Record 32 of Set 9 | lata
# Processing Record 33 of Set 9 | manokwari
# Processing Record 34 of Set 9 | labrador city
# Processing Record 35 of Set 9 | malmberget
# Processing Record 36 of Set 9 | ippy
# Processing Record 37 of Set 9 | abadeh
# Processing Record 38 of Set 9 | salto del guaira
# Processing Record 39 of Set 9 | loen
# Processing Record 40 of Set 9 | powell river
# Processing Record 41 of Set 9 | blenheim
# Processing Record 42 of Set 9 | yangor
# City not found. Skipping...
# Processing Record 43 of Set 9 | yelizovo
# Processing Record 44 of Set 9 | sibolga
# Processing Record 45 of Set 9 | oum hadjer
# Processing Record 46 of Set 9 | cidade velha
# Processing Record 47 of Set 9 | vanimo
# Processing Record 48 of Set 9 | lerwick
# Processing Record 49 of Set 9 | noshiro
# Processing Record 0 of Set 10 | impfondo
# Processing Record 1 of Set 10 | christchurch
# Processing Record 2 of Set 10 | mayma
# Processing Record 3 of Set 10 | cozumel
# Processing Record 4 of Set 10 | afaahiti
# Processing Record 5 of Set 10 | rexburg
# Processing Record 6 of Set 10 | paramonga
# Processing Record 7 of Set 10 | saint-francois
# Processing Record 8 of Set 10 | castillos
# Processing Record 9 of Set 10 | mili
# Processing Record 10 of Set 10 | shimoda
# Processing Record 11 of Set 10 | voinjama
# Processing Record 12 of Set 10 | kapit
# Processing Record 13 of Set 10 | krasnogorskiy
# Processing Record 14 of Set 10 | nova sintra
# Processing Record 15 of Set 10 | maluso
# Processing Record 16 of Set 10 | amungan
# Processing Record 17 of Set 10 | vitebsk
# Processing Record 18 of Set 10 | port saint john's
# Processing Record 19 of Set 10 | bikenibeu village
# Processing Record 20 of Set 10 | qusmuryn
# Processing Record 21 of Set 10 | fatsa
# Processing Record 22 of Set 10 | emerald
# Processing Record 23 of Set 10 | trincomalee
# Processing Record 24 of Set 10 | siracusa
# Processing Record 25 of Set 10 | koryazhma
# Processing Record 26 of Set 10 | pearsall
# Processing Record 27 of Set 10 | mata-utu
# Processing Record 28 of Set 10 | murudeshwara
# Processing Record 29 of Set 10 | mezhdurechensk
# Processing Record 30 of Set 10 | berdigestyakh
# Processing Record 31 of Set 10 | joshimath
# Processing Record 32 of Set 10 | el burgo de osma
# Processing Record 33 of Set 10 | sovetskiy
# Processing Record 34 of Set 10 | rechytsa
# Processing Record 35 of Set 10 | nar'yan-mar
# Processing Record 36 of Set 10 | cabedelo
# Processing Record 37 of Set 10 | kingston
# Processing Record 38 of Set 10 | neyriz
# Processing Record 39 of Set 10 | arkalyk
# Processing Record 40 of Set 10 | tubarjal
# Processing Record 41 of Set 10 | puerto colombia
# Processing Record 42 of Set 10 | el cuervo
# Processing Record 43 of Set 10 | wad az zaki
# Processing Record 44 of Set 10 | la'ie
# Processing Record 45 of Set 10 | javea
# Processing Record 46 of Set 10 | kalianget
# Processing Record 47 of Set 10 | sungailiat
# Processing Record 48 of Set 10 | nadi
# Processing Record 49 of Set 10 | belyy yar
# Processing Record 0 of Set 11 | nabire
# Processing Record 1 of Set 11 | margate
# Processing Record 2 of Set 11 | manado
# Processing Record 3 of Set 11 | riachao das neves
# Processing Record 4 of Set 11 | perry
# Processing Record 5 of Set 11 | kotma
# Processing Record 6 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 11 | bela
# Processing Record 8 of Set 11 | takamaka
# City not found. Skipping...
# Processing Record 9 of Set 11 | hohhot
# Processing Record 10 of Set 11 | midvagur
# Processing Record 11 of Set 11 | hunstanton
# Processing Record 12 of Set 11 | turpan
# Processing Record 13 of Set 11 | ridgecrest
# Processing Record 14 of Set 11 | sonsorol village
# City not found. Skipping...
# Processing Record 15 of Set 11 | north haven
# Processing Record 16 of Set 11 | daura
# Processing Record 17 of Set 11 | eyl
# Processing Record 18 of Set 11 | jayapura
# Processing Record 19 of Set 11 | khandyga
# Processing Record 20 of Set 11 | apac
# Processing Record 21 of Set 11 | linden
# Processing Record 22 of Set 11 | kayyerkan
# Processing Record 23 of Set 11 | westerland
# Processing Record 24 of Set 11 | xinglongshan
# Processing Record 25 of Set 11 | sofiyivska borschagivka
# City not found. Skipping...
# Processing Record 26 of Set 11 | tromso
# Processing Record 27 of Set 11 | saudarkrokur
# Processing Record 28 of Set 11 | martapura
# Processing Record 29 of Set 11 | fuglafjordur
# Processing Record 30 of Set 11 | kerikeri
# Processing Record 31 of Set 11 | port lavaca
# Processing Record 32 of Set 11 | santa cruz
# Processing Record 33 of Set 11 | tynda
# Processing Record 34 of Set 11 | padang
# Processing Record 35 of Set 11 | cockburn town
# Processing Record 36 of Set 11 | i-n-salah
# Processing Record 37 of Set 11 | ilha de mocambique
# Processing Record 38 of Set 11 | uricani
# Processing Record 39 of Set 11 | tokar
# Processing Record 40 of Set 11 | siwa oasis
# Processing Record 41 of Set 11 | san felipe
# Processing Record 42 of Set 11 | magong
# Processing Record 43 of Set 11 | dhalie
# Processing Record 44 of Set 11 | bibiani
# Processing Record 45 of Set 11 | kolpashevo
# Processing Record 46 of Set 11 | salinopolis
# Processing Record 47 of Set 11 | tual
# Processing Record 48 of Set 11 | nantucket
# Processing Record 49 of Set 11 | kruisfontein
# Processing Record 0 of Set 12 | ocean shores
# Processing Record 1 of Set 12 | antonio enes
# Processing Record 2 of Set 12 | san jose
# Processing Record 3 of Set 12 | kismayo
# Processing Record 4 of Set 12 | newman
# Processing Record 5 of Set 12 | leava
# Processing Record 6 of Set 12 | piti village
# Processing Record 7 of Set 12 | shabqadar
# Processing Record 8 of Set 12 | general acha
# Processing Record 9 of Set 12 | saldanha
# Processing Record 10 of Set 12 | findlay
# Processing Record 11 of Set 12 | robore
# Processing Record 12 of Set 12 | patong
# Processing Record 13 of Set 12 | kuching
# Processing Record 14 of Set 12 | campbell river
# Processing Record 15 of Set 12 | aberdeen
# Processing Record 16 of Set 12 | baglung
# Processing Record 17 of Set 12 | sarandi del yi
# Processing Record 18 of Set 12 | ras gharib
# City not found. Skipping...
# Processing Record 19 of Set 12 | bassano del grappa
# Processing Record 20 of Set 12 | dhidhdhoo
# Processing Record 21 of Set 12 | san fernando de apure
# Processing Record 22 of Set 12 | sumbe
# Processing Record 23 of Set 12 | adh dhibiyah
# Processing Record 24 of Set 12 | komsomol'skiy
# Processing Record 25 of Set 12 | red lion
# Processing Record 26 of Set 12 | loiza
# Processing Record 27 of Set 12 | mihara
# Processing Record 28 of Set 12 | fortaleza
# Processing Record 29 of Set 12 | strathmore
# Processing Record 30 of Set 12 | taos
# Processing Record 31 of Set 12 | zapolyarnyy
# Processing Record 32 of Set 12 | toga village
# City not found. Skipping...
# Processing Record 33 of Set 12 | koneurgench
# City not found. Skipping...
# Processing Record 34 of Set 12 | mugia
# Processing Record 35 of Set 12 | sidi salim
# Processing Record 36 of Set 12 | timmins
# Processing Record 37 of Set 12 | kelibia
# Processing Record 38 of Set 12 | kapa'a
# Processing Record 39 of Set 12 | ilagan
# Processing Record 40 of Set 12 | solleftea
# Processing Record 41 of Set 12 | san pedro
# Processing Record 42 of Set 12 | palikir - national government center
# Processing Record 43 of Set 12 | nevinnomyssk
# Processing Record 44 of Set 12 | guerrero
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          566
# Lat           566
# Lng           566
# Max Temp      566
# Humidity      566
# Cloudiness    566
# Wind Speed    566
# Country       566
# Date          566
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#      City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  bethel  41.3712  -73.4140     20.05        90         100        3.60
# 1   mirny  62.5353  113.9611     14.68        68          11        1.49
# 2  camana -16.6228  -72.7111     16.25        81          63        4.76
# 3   tiksi  71.6872  128.8694      5.83        90         100        5.21
# 4    miri   4.4148  114.0089     25.08        94          40        2.57
#
#   Country        Date
# 0      US  1723150292
# 1      RU  1723150293
# 2      PE  1723150294
# 3      RU  1723150296
# 4      MY  1723150297

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        bethel  41.3712  -73.4140     20.05        90         100
# 1         mirny  62.5353  113.9611     14.68        68          11
# 2        camana -16.6228  -72.7111     16.25        81          63
# 3         tiksi  71.6872  128.8694      5.83        90         100
# 4          miri   4.4148  114.0089     25.08        94          40
#
#          Wind Speed Country        Date
# City_ID
# 0              3.60      US  1723150292
# 1              1.49      RU  1723150293
# 2              4.76      PE  1723150294
# 3              5.21      RU  1723150296
# 4              2.57      MY  1723150297

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df["Max Temp"], marker='o')

# Incorporate the other graph properties
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Temperature (C)")
plt.title("City Max Latitude vs. Max Temperature (2024-06-17)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df["Humidity"], marker='o')

# Incorporate the other graph properties
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2024-06-17)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df["Cloudiness"], marker='o')

# Incorporate the other graph properties
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2024-06-17)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df["Wind Speed"], marker='o')

# Incorporate the other graph properties
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Cloudiness (2024-06-17)")
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label):
    slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=12, color="red")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(f"The r^2-value is: {rvalue**2}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0, :]
# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             bethel  41.3712  -73.4140     20.05        90         100
# 1              mirny  62.5353  113.9611     14.68        68          11
# 3              tiksi  71.6872  128.8694      5.83        90         100
# 4               miri   4.4148  114.0089     25.08        94          40
# 12       bridgewater  44.3835  -64.5155     25.06        64          15
#
#          Wind Speed Country        Date
# City_ID
# 0              3.60      US  1723150292
# 1              1.49      RU  1723150293
# 3              5.21      RU  1723150296
# 4              2.57      MY  1723150297
# 12             4.12      CA  1723150308

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]<0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2                   camana -16.6228  -72.7111     16.25        81          63
# 5           puerto natales -51.7236  -72.4875     11.25        58          75
# 6                adamstown -25.0660 -130.1015     21.57        79          58
# 7        port-aux-francais -49.3500   70.2167      1.97        77          92
# 8                  chonchi -42.6128  -73.8092      7.67        88          99
#
#          Wind Speed Country        Date
# City_ID
# 2              4.76      PE  1723150294
# 5              8.23      CL  1723150299
# 6             10.44      PN  1723150301
# 7              8.73      TF  1723150302
# 8              0.73      CL  1723150303

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

   
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=12, color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Latitude vs Max Temperature")

print (f"The r^2-value is: {rvalue**2}")

plt.show()
# Out:
# The r^2-value is: 0.44985980712783913

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df["Max Temp"]

slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=12, color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Latitude VS Max Temperature")

print(f"The r^2-value is: {rvalue**2}")

plt.show()
# Out:
# The r^2-value is: 0.7165367599157049

# %% [markdown]
# **Discussion about the linear relationship:** After looking at the data on these charts, we are able to see that the Northern Hemisphere shows a negative regression while the Southern Hemisphere shows a positive regression slope. We can see that at a higher latitude, the Northern Hemisphere the temperature will likely drop and the Souther Hemisphere the temperature will likely rise.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=12, color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude VS Humidity")

print(f"The r^2-value is: {rvalue**2}")

plt.show()
# Out:
# The r^2-value is: 0.0002427973205534048

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=12, color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude VS Humidity")

print(f"The r^2-value is: {rvalue**2}")

plt.show()
# Out:
# The r^2-value is: 0.0009964031961959897

# %% [markdown]
# **Discussion about the linear relationship:With the data pulled for these charts, the information shows that there is a very slight difference in the humidity between the Northern and Southern Hemisphere depending on the Latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=12, color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude VS Cloudiness")

print(f"The r^2-value is: {rvalue**2}")

plt.show()
# Out:
# The r^2-value is: 0.017346491778863753

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=12, color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude VS Cloudiness")

print(f"The r^2-value is: {rvalue**2}")

plt.show()
# Out:
# The r^2-value is: 0.023162398003526923

# %% [markdown]
# **Discussion about the linear relationship:** Both charts show that dependant on the data, there is a slight negative correlation in both the Northern and Southern Hemisphere between the cloudiness and latitude of the hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=12, color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude VS Wind Speed")

print(f"The r^2-value is: {rvalue**2}")

plt.show()
# Out:
# The r^2-value is: 0.004057348956107944

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=12, color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude VS Wind Speed")

print(f"The r^2-value is: {rvalue**2}")

plt.show()
# Out:
# The r^2-value is: 0.004057348956107944

# %% [markdown]
# **Discussion about the linear relationship:** Both charts show that dependant on the data, there is a slight negative correlation in both the Northern and Southern Hemisphere between the wind speed and latitude of the hemisphere.
